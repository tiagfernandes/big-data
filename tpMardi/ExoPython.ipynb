# %% [markdown]
# # Exercices

# %% [markdown]
# ## Exo 1

# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sb
import matplotlib.pyplot as plt

# %%
data_path = '../data/house_pricing.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(data_path) 
df
# Out:
#         Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0        1          60       RL         65.0     8450   Pave   NaN      Reg
# 1        2          20       RL         80.0     9600   Pave   NaN      Reg
# 2        3          60       RL         68.0    11250   Pave   NaN      IR1
# 3        4          70       RL         60.0     9550   Pave   NaN      IR1
# 4        5          60       RL         84.0    14260   Pave   NaN      IR1
# ...    ...         ...      ...          ...      ...    ...   ...      ...
# 1455  1456          60       RL         62.0     7917   Pave   NaN      Reg
# 1456  1457          20       RL         85.0    13175   Pave   NaN      Reg
# 1457  1458          70       RL         66.0     9042   Pave   NaN      Reg
# 1458  1459          20       RL         68.0     9717   Pave   NaN      Reg
# 1459  1460          20       RL         75.0     9937   Pave   NaN      Reg
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1460 entries, 0 to 1459
# Data columns (total 81 columns):
# Id               1460 non-null int64
# MSSubClass       1460 non-null int64
# MSZoning         1460 non-null object
# LotFrontage      1201 non-null float64
# LotArea          1460 non-null int64
# Street           1460 non-null object
# Alley            91 non-null object
# LotShape         1460 non-null object
# LandContour      1460 non-null object
# Utilities        1460 non-null object
# LotConfig        1460 non-null object
# LandSlope        1460 non-null object
# Neighborhood     1460 non-null object
# Condition1       1460 non-null object
# Condition2       1460 non-null object
# BldgType         1460 non-null object
# HouseStyle       1460 non-null object
# OverallQual      1460 non-null int64
# OverallCond      1460 non-null int64
# YearBuilt        1460 non-null int64
# YearRemodAdd     1460 non-null int64
# RoofStyle        1460 non-null object
# ...

# %%
df.describe(include='all')
# Out:
#                  Id   MSSubClass MSZoning  LotFrontage        LotArea Street  \
# count   1460.000000  1460.000000     1460  1201.000000    1460.000000   1460
# unique          NaN          NaN        5          NaN            NaN      2
# top             NaN          NaN       RL          NaN            NaN   Pave
# freq            NaN          NaN     1151          NaN            NaN   1454
# mean     730.500000    56.897260      NaN    70.049958   10516.828082    NaN
# std      421.610009    42.300571      NaN    24.284752    9981.264932    NaN
# min        1.000000    20.000000      NaN    21.000000    1300.000000    NaN
# 25%      365.750000    20.000000      NaN    59.000000    7553.500000    NaN
# 50%      730.500000    50.000000      NaN    69.000000    9478.500000    NaN
# 75%     1095.250000    70.000000      NaN    80.000000   11601.500000    NaN
# max     1460.000000   190.000000      NaN   313.000000  215245.000000    NaN
#
# ...

# %%
sb.set(style="darkgrid")
sb.scatterplot(x="LotArea", y="SalePrice", data=df)

# %%
data = df[(df['LotArea'] < 20000) & (df['SalePrice'] < 500000)]

sb.scatterplot(x="LotArea", y="SalePrice", data=data)

# %%
sb.scatterplot(x="LotArea", y="LotFrontage", data=data)

# %%
data = df[(df['LotArea'] < 100000) & (df['LotFrontage'] < 200)]
sb.scatterplot(x="LotArea", y="LotFrontage", data=data)

# %% [markdown]
# ## Exo 2

# %%
data_path = '../data/sales_predictions.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(data_path) 
df
# Out:
#                date  date_block_num  shop_id  item_id  item_price  \
# 0        02.01.2013               0       59    22154      999.00
# 1        03.01.2013               0       25     2552      899.00
# 2        05.01.2013               0       25     2552      899.00
# 3        06.01.2013               0       25     2554     1709.05
# 4        15.01.2013               0       25     2555     1099.00
# ...             ...             ...      ...      ...         ...
# 2935844  10.10.2015              33       25     7409      299.00
# 2935845  09.10.2015              33       25     7460      299.00
# 2935846  14.10.2015              33       25     7459      349.00
# 2935847  22.10.2015              33       25     7440      299.00
# 2935848  03.10.2015              33       25     7460      299.00
#
#          item_cnt_day
# 0                 1.0
# 1                 1.0
# 2                -1.0
# 3                 1.0
# 4                 1.0
# ...               ...
# ...

# %%
sb.relplot(x="date", y="item_price", data=df)

# %% [markdown]
# Chargement long puisqu'il y a ~3M de lignes, mais dans le temps le prix a tendance à monté

# %%
sb.relplot(x="date", y="item_price", data=df.sample(50))

# %%
graph = sb.relplot(x="date", y="item_price", data=df.sample(n=50), sizes=(20,6))
graph.fig.set_figwidth(20)
graph.fig.set_figheight(6)

# %% [markdown]
# C'est plus facilement lisible

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              object
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: float64(2), int64(3), object(1)
# memory usage: 134.4+ MB

# %%
df['date'] = pd.to_datetime(df['date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2935849 entries, 0 to 2935848
# Data columns (total 6 columns):
# date              datetime64[ns]
# date_block_num    int64
# shop_id           int64
# item_id           int64
# item_price        float64
# item_cnt_day      float64
# dtypes: datetime64[ns](1), float64(2), int64(3)
# memory usage: 134.4 MB

# %%
graph = sb.relplot(x="date", y="item_price", data=df.sample(n=50), sizes=(20,6))
graph.fig.set_figwidth(20)
graph.fig.set_figheight(6)
# Out:
# /home/tiago/.local/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# Plus facilement lisible en utilisant l'objet datetime64

# %% [markdown]
# ## Exo 3

# %%
data_path = '../data/IBM_HR_ATTRITION.csv'
pd.set_option('display.max_columns', None)
df3 = pd.read_csv(data_path) 
df3
# Out:
#       Age Attrition     BusinessTravel  DailyRate              Department  \
# 0      41       Yes      Travel_Rarely       1102                   Sales
# 1      49        No  Travel_Frequently        279  Research & Development
# 2      37       Yes      Travel_Rarely       1373  Research & Development
# 3      33        No  Travel_Frequently       1392  Research & Development
# 4      27        No      Travel_Rarely        591  Research & Development
# ...   ...       ...                ...        ...                     ...
# 1465   36        No  Travel_Frequently        884  Research & Development
# 1466   39        No      Travel_Rarely        613  Research & Development
# 1467   27        No      Travel_Rarely        155  Research & Development
# 1468   49        No  Travel_Frequently       1023                   Sales
# 1469   34        No      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sb.catplot(x="Attrition", y="JobSatisfaction", data=df3, kind="bar")

# %%
sb.catplot(x="Attrition", y="JobSatisfaction", data=df3, kind="box")

# %% [markdown]
# Que 75% des gens qui sont partis, on attribués une note entre 1 et 3. Et que 75% des gens qui reste attribus une note entre 2 et 4.

# %% [markdown]
# Il y a aucune valeure aberrante

# %% [markdown]
# Ne sert à rien

# %%
df3.describe()
# Out:
#                Age    DailyRate  DistanceFromHome    Education  EmployeeCount  \
# count  1470.000000  1470.000000       1470.000000  1470.000000         1470.0
# mean     36.923810   802.485714          9.192517     2.912925            1.0
# std       9.135373   403.509100          8.106864     1.024165            0.0
# min      18.000000   102.000000          1.000000     1.000000            1.0
# 25%      30.000000   465.000000          2.000000     2.000000            1.0
# 50%      36.000000   802.000000          7.000000     3.000000            1.0
# 75%      43.000000  1157.000000         14.000000     4.000000            1.0
# max      60.000000  1499.000000         29.000000     5.000000            1.0
#
#        EmployeeNumber  EnvironmentSatisfaction   HourlyRate  JobInvolvement  \
# count     1470.000000              1470.000000  1470.000000     1470.000000
# mean      1024.865306                 2.721769    65.891156        2.729932
# ...

# %% [markdown]
# Aucune valeur aberrante donc on ne peu comparer

# %%
sb.catplot(x="Attrition", y="TotalWorkingYears", data=df3, kind="bar")

# %%
sb.catplot(x="Attrition", y="TotalWorkingYears", data=df3, kind="box")

# %% [markdown]
# 1 mec est parti après 40 ans de carrière. 75% des personnes partes avant les 10 ans, et 75% des gens qui y sont encore sous les 16-17 ans de carrière.

# %%
df3.Attrition = df3.Attrition.replace({"Yes":1, "No":0})
df3
# Out:
#       Age  Attrition     BusinessTravel  DailyRate              Department  \
# 0      41          1      Travel_Rarely       1102                   Sales
# 1      49          0  Travel_Frequently        279  Research & Development
# 2      37          1      Travel_Rarely       1373  Research & Development
# 3      33          0  Travel_Frequently       1392  Research & Development
# 4      27          0      Travel_Rarely        591  Research & Development
# ...   ...        ...                ...        ...                     ...
# 1465   36          0  Travel_Frequently        884  Research & Development
# 1466   39          0      Travel_Rarely        613  Research & Development
# 1467   27          0      Travel_Rarely        155  Research & Development
# 1468   49          0  Travel_Frequently       1023                   Sales
# 1469   34          0      Travel_Rarely        628  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  \
# ...

# %%
sb.catplot(x="Attrition", y="TotalWorkingYears", data=df3, kind="box")

# %%
sb.catplot(x="Attrition", y="EducationField", data=df3, kind="bar", hue="Department")

# %% [markdown]
# # Exo 4

# %%
sb.distplot(df3.MonthlyIncome)

# %%
data = df3.query('MonthlyIncome <= 5000')
sb.distplot(data.MonthlyIncome)

# %% [markdown]
# # Exo 5

# %%
sb.lmplot(x="DistanceFromHome", y="Attrition", data=df3)

# %% [markdown]
# Plus les gens habitent proches, plus ils ont tendances à vouloir rester dans l'entreprise. Mais plus ils sont distant et c'est assez variable.

# %%
sb.lmplot(x="YearsWithCurrManager", y="Attrition", data=df3)

# %% [markdown]
# Plus une personne reste avec le manager et plus la personne à tendance à rester

# %% [markdown]
# # Exo 5

# %%
data_path = '../data/house_pricing.csv'
pd.set_option('display.max_columns', None)
df = pd.read_csv(data_path) 
lastColumns = df[df.columns[-15:]]
lastColumns
# Out:
#       WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# 0              0           61              0          0            0
# 1            298            0              0          0            0
# 2              0           42              0          0            0
# 3              0           35            272          0            0
# 4            192           84              0          0            0
# ...          ...          ...            ...        ...          ...
# 1455           0           40              0          0            0
# 1456         349            0              0          0            0
# 1457           0           60              0          0            0
# 1458         366            0            112          0            0
# 1459         736           68              0          0            0
#
#       PoolArea PoolQC  Fence MiscFeature  MiscVal  MoSold  YrSold SaleType  \
# ...

# %%
lastColumns.corr()
# Out:
#                WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  \
# WoodDeckSF       1.000000     0.058661      -0.125989  -0.032771    -0.074181
# OpenPorchSF      0.058661     1.000000      -0.093079  -0.005842     0.074304
# EnclosedPorch   -0.125989    -0.093079       1.000000  -0.037305    -0.082864
# 3SsnPorch       -0.032771    -0.005842      -0.037305   1.000000    -0.031436
# ScreenPorch     -0.074181     0.074304      -0.082864  -0.031436     1.000000
# PoolArea         0.073378     0.060762       0.054203  -0.007992     0.051307
# MiscVal         -0.009551    -0.018584       0.018361   0.000354     0.031946
# MoSold           0.021011     0.071255      -0.028887   0.029474     0.023217
# YrSold           0.022270    -0.057619      -0.009916   0.018645     0.010694
# SalePrice        0.324413     0.315856      -0.128578   0.044584     0.111447
#
#                PoolArea   MiscVal    MoSold    YrSold  SalePrice
# ...

# %%
plt.subplots(figsize=(20,15))
sb.heatmap(lastColumns.corr(), annot=True)

# %% [markdown]
# *Le Top 3 :*
#
# **WoodDeckSF** = 0.32
#
# **OpenPortchSF** = 0.32
#
# **ScreenPorche** = 0.11
